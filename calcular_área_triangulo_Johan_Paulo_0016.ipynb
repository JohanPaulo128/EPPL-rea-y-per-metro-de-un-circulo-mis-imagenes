# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/blob/main/calcular_%C3%A1rea_triangulo_Johan_Paulo_0016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Johan Paulo Aros reveles Fecha 27/Marzo/2026
# ![Logo de Markdown](https://raw.githubusercontent.com/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/refs/heads/main/triangulo_formula.webp)
# ---
# # Formula para calcular area de triangulo
# $$Área = \frac{base \times altura}{2}$$
# #Datos de entrada
# b = ?
# h = ?
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/refs/heads/main/Diagrama%20de%20flujo%20de%20triangulo.png)

# %%
# Calcular area de un triagulo
# Variables b,h
# Fromula para calcular b*h/2
# Capturar el valor de r
b = float(input("Ingrese el valor de la base: "))
h = float(input("Ingrese el valor de la altura: "))
area = (b*h)/2
print("El area del triangulo es: ", area)
print("Johan Paulo Aros 0016")

# %% [markdown]
# # Relacion entre codigo y DF en tildraw
# ![Logo de Markdown](https://raw.githubusercontent.com/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20de%20triangulo.png)
