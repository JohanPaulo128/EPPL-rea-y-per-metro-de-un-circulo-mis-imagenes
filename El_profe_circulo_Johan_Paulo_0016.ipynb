# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/blob/main/El_profe_circulo_Johan_Paulo_0016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Johan Paulo Aros Reveles fecha 25/Marzo/2026 ♾
# ---
# # Calculr area de un circulo
# ![Logo de Markdown](https://raw.githubusercontent.com/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/refs/heads/main/Area%20circulo.jpg)
#
# Formula para calcular area
# $A=\pi*r^2$
#
# ---
# ## Formula para calcular perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# %r% ?
# ---
# ## Diagrama de flujo en LucidChart
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# Calcular area y perimetro de un circulo
# Vriables A, P, r
# Formula A = pi*r^2 y P = 2 * pi * r
# Capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor de r: "))
A = math.pi * r**2
P = 2 * math.pi * r
print("El area del circulo es: ", A)
print("El perimetro del circulo es: ", P)
("Johan Paulo 0016 Nl = 4")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor de r: 8
# El area del circulo es:  201.06192982974676
# El perimetro del circulo es:  50.26548245743669
# 'Johan Paulo 0016 Nl = 4'

# %% [markdown]
# # Relacion entre codigo y DF en tildraw
# ![Logo de Markdown](https://raw.githubusercontent.com/JohanPaulo128/EPPL-rea-y-per-metro-de-un-circulo-mis-imagenes/refs/heads/main/tldraw%20DF%20y%20Codigo.png)
